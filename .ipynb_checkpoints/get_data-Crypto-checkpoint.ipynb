# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
from zipfile import ZipFile
from os import listdir
from os.path import isfile, join
import datetime
import time
import os
import numpy as np

# %%
directory = '../FX-1-Minute-Data/output'
folders = [x[0].split('\\')[-1] for x in os.walk(directory)][1:]
data = pd.DataFrame()
for folder in folders:
    zip_files = [f for f in listdir(f'{directory}/{folder}') if f.endswith('.zip') and '2021' not in f and 'USD' in f]

    for file in zip_files:
        print(file)
        zip_file = ZipFile(f'{directory}/{folder}/{file}')
        df = pd.read_csv(zip_file.open(file[:-4]+'.csv'), names=['datetime', 'open', 'high', 'low', 'close', 'volume'], sep=';')
        df = df[['datetime', 'close']]
        df['datetime'] = df['datetime'].apply(lambda x: datetime.datetime.strptime(x, '%Y%m%d %H%M%S'))
        df = df.set_index('datetime')
        df = df[~df.index.duplicated()]
        df = df.resample('1T').fillna(None)
        
        temp = (~df.isna()).cumsum()
        seq_len = 513
        df['index'] = np.concatenate((((temp[seq_len:].values - temp[:-seq_len].values) == [seq_len])[:,0], [False]*seq_len))
        print(df['index'].sum(), len(df), data['index'].sum())
        
        close_log = 100*50*(df.iloc[1:]['close'].values - df.iloc[:-1]['close'].values)/df.iloc[:-1]['close'].values
        close_log = np.concatenate((np.sign(close_log)*np.log(abs(close_log)+1)))
        df['close_log'] = close_log
        
        df['file'] = file
        data = data.append(df)
#         np.savez('data/forex/' + file[:-4], a=np.array(seqs))
# Out:
# DAT_ASCII_AUDUSD_M1_2000.zip
# 0 298004 0
# DAT_ASCII_AUDUSD_M1_2001.zip
# 0 449158 298004
# DAT_ASCII_AUDUSD_M1_2002.zip
# 0 523410 747162
# DAT_ASCII_AUDUSD_M1_2003.zip
# 10606 523911 1270572
# DAT_ASCII_AUDUSD_M1_2004.zip
# 8379 525447 1794483
# DAT_ASCII_AUDUSD_M1_2005.zip
# 0 519310 2319930
# DAT_ASCII_AUDUSD_M1_2006.zip
# 0 519674 2839240
# DAT_ASCII_AUDUSD_M1_2007.zip
# 0 523976 3358914
# DAT_ASCII_AUDUSD_M1_2008.zip
# 1954 525419 3882890
# DAT_ASCII_AUDUSD_M1_2009.zip
# 11932 524041 4408309
# DAT_ASCII_AUDUSD_M1_2010.zip
# 18787 521159 4932350
# DAT_ASCII_AUDUSD_M1_2011.zip
# 44499 521279 5453509
# DAT_ASCII_AUDUSD_M1_2012.zip
# 160336 525059 5974788
# DAT_ASCII_AUDUSD_M1_2013.zip
# 158401 524100 6499847
# DAT_ASCII_AUDUSD_M1_2014.zip
# 78133 524158 7023947
# DAT_ASCII_AUDUSD_M1_2015.zip
# 164932 524398 7548105
# DAT_ASCII_AUDUSD_M1_2016.zip
# 183786 521278 8072503
# DAT_ASCII_AUDUSD_M1_2017.zip
# 122806 520738 8593781
# DAT_ASCII_AUDUSD_M1_2018.zip
# 140704 524159 9114519
# DAT_ASCII_AUDUSD_M1_2019.zip
# 242867 524159 9638678
# DAT_ASCII_AUDUSD_M1_2020.zip
# 211050 525599 10162837
# DAT_ASCII_BCOUSD_M1_2010.zip
# 1656 67365 10688436
# DAT_ASCII_BCOUSD_M1_2011.zip
# 31216 521084 10755801
# DAT_ASCII_BCOUSD_M1_2012.zip
# 19398 523859 11276885
# DAT_ASCII_BCOUSD_M1_2013.zip
# 6505 523858 11800744
# DAT_ASCII_BCOUSD_M1_2014.zip
# 3523 523859 12324602
# DAT_ASCII_BCOUSD_M1_2015.zip
# 19331 523859 12848461
# DAT_ASCII_BCOUSD_M1_2016.zip
# 14116 521099 13372320
# DAT_ASCII_BCOUSD_M1_2017.zip
# 640 519536 13893419
# DAT_ASCII_BCOUSD_M1_2018.zip
# 22648 523827 14412955
# DAT_ASCII_BCOUSD_M1_2019.zip
# 54177 523859 14936782
# DAT_ASCII_BCOUSD_M1_2020.zip
# 82898 525299 15460641
# DAT_ASCII_EURUSD_M1_2000.zip
# 0 306359 15985940
# DAT_ASCII_EURUSD_M1_2001.zip
# 0 523271 16292299
# DAT_ASCII_EURUSD_M1_2002.zip
# 0 523413 16815570
# DAT_ASCII_EURUSD_M1_2003.zip
# 36123 523919 17338983
# DAT_ASCII_EURUSD_M1_2004.zip
# 12193 525449 17862902
# DAT_ASCII_EURUSD_M1_2005.zip
# 162 519311 18388351
# DAT_ASCII_EURUSD_M1_2006.zip
# 0 519689 18907662
# DAT_ASCII_EURUSD_M1_2007.zip
# 243 523978 19427351
# DAT_ASCII_EURUSD_M1_2008.zip
# 29192 525419 19951329
# DAT_ASCII_EURUSD_M1_2009.zip
# 30914 524039 20476748
# DAT_ASCII_EURUSD_M1_2010.zip
# 26786 521159 21000787
# DAT_ASCII_EURUSD_M1_2011.zip
# 66066 521279 21521946
# DAT_ASCII_EURUSD_M1_2012.zip
# 222081 525059 22043225
# DAT_ASCII_EURUSD_M1_2013.zip
# 164226 524100 22568284
# DAT_ASCII_EURUSD_M1_2014.zip
# 117275 524160 23092384
# DAT_ASCII_EURUSD_M1_2015.zip
# 241963 524399 23616544
# DAT_ASCII_EURUSD_M1_2016.zip
# 251366 521279 24140943
# DAT_ASCII_EURUSD_M1_2017.zip
# 218741 520738 24662222
# DAT_ASCII_EURUSD_M1_2018.zip
# 222097 524160 25182960
# DAT_ASCII_EURUSD_M1_2019.zip
# 298798 524158 25707120
# DAT_ASCII_EURUSD_M1_2020.zip
# 233186 525599 26231278
# DAT_ASCII_GBPUSD_M1_2000.zip
# 0 306328 26756877
# DAT_ASCII_GBPUSD_M1_2001.zip
# 0 523271 27063205
# DAT_ASCII_GBPUSD_M1_2002.zip
# 0 523412 27586476
# DAT_ASCII_GBPUSD_M1_2003.zip
# 16939 523914 28109888
# DAT_ASCII_GBPUSD_M1_2004.zip
# 11689 525448 28633802
# DAT_ASCII_GBPUSD_M1_2005.zip
# 791 519310 29159250
# DAT_ASCII_GBPUSD_M1_2006.zip
# 213 519691 29678560
# DAT_ASCII_GBPUSD_M1_2007.zip
# 914 523978 30198251
# DAT_ASCII_GBPUSD_M1_2008.zip
# 21599 525419 30722229
# DAT_ASCII_GBPUSD_M1_2009.zip
# 55306 524041 31247648
# DAT_ASCII_GBPUSD_M1_2010.zip
# 41973 521160 31771689
# DAT_ASCII_GBPUSD_M1_2011.zip
# 39854 521279 32292849
# DAT_ASCII_GBPUSD_M1_2012.zip
# 198748 525059 32814128
# DAT_ASCII_GBPUSD_M1_2013.zip
# 195700 524100 33339187
# DAT_ASCII_GBPUSD_M1_2014.zip
# 154826 524159 33863287
# DAT_ASCII_GBPUSD_M1_2015.zip
# 254602 524398 34387446
# DAT_ASCII_GBPUSD_M1_2016.zip
# 230175 521278 34911844
# DAT_ASCII_GBPUSD_M1_2017.zip
# 193621 520738 35433122
# DAT_ASCII_GBPUSD_M1_2018.zip
# 202702 524159 35953860
# DAT_ASCII_GBPUSD_M1_2019.zip
# 287385 524153 36478019
# DAT_ASCII_GBPUSD_M1_2020.zip
# 276993 525597 37002172
# DAT_ASCII_NSXUSD_M1_2010.zip
# 1110 67499 37527769
# DAT_ASCII_NSXUSD_M1_2011.zip
# 35210 521165 37595268
# DAT_ASCII_NSXUSD_M1_2012.zip
# 19305 523379 38116433
# DAT_ASCII_NSXUSD_M1_2013.zip
# 4763 523319 38639812
# DAT_ASCII_NSXUSD_M1_2014.zip
# 19153 524086 39163131
# DAT_ASCII_NSXUSD_M1_2015.zip
# 66573 524099 39687217
# DAT_ASCII_NSXUSD_M1_2016.zip
# 74104 521218 40211316
# DAT_ASCII_NSXUSD_M1_2017.zip
# 23498 519779 40732534
# DAT_ASCII_NSXUSD_M1_2018.zip
# 153446 524144 41252313
# DAT_ASCII_NSXUSD_M1_2019.zip
# 186311 524054 41776457
# DAT_ASCII_NSXUSD_M1_2020.zip
# 198642 525494 42300511
# DAT_ASCII_NZDUSD_M1_2005.zip
# 0 200157 42826005
# DAT_ASCII_NZDUSD_M1_2006.zip
# 0 519688 43026162
# DAT_ASCII_NZDUSD_M1_2007.zip
# 0 523978 43545850
# DAT_ASCII_NZDUSD_M1_2008.zip
# 0 525415 44069828
# DAT_ASCII_NZDUSD_M1_2009.zip
# 0 524041 44595243
# DAT_ASCII_NZDUSD_M1_2010.zip
# 0 521156 45119284
# DAT_ASCII_NZDUSD_M1_2011.zip
# 11816 521279 45640440
# DAT_ASCII_NZDUSD_M1_2012.zip
# 164627 525058 46161719
# DAT_ASCII_NZDUSD_M1_2013.zip
# 107612 524100 46686777
# DAT_ASCII_NZDUSD_M1_2014.zip
# 84072 524158 47210877
# DAT_ASCII_NZDUSD_M1_2015.zip
# 151191 524399 47735035
# DAT_ASCII_NZDUSD_M1_2016.zip
# 190674 521279 48259434
# DAT_ASCII_NZDUSD_M1_2017.zip
# 113884 520737 48780713
# DAT_ASCII_NZDUSD_M1_2018.zip
# 128141 524157 49301450
# DAT_ASCII_NZDUSD_M1_2019.zip
# 255493 524157 49825607
# DAT_ASCII_NZDUSD_M1_2020.zip
# 198197 525599 50349764
# DAT_ASCII_SPXUSD_M1_2010.zip
# 0 67498 50875363
# DAT_ASCII_SPXUSD_M1_2011.zip
# 6094 521166 50942861
# DAT_ASCII_SPXUSD_M1_2012.zip
# 96 523379 51464027
# DAT_ASCII_SPXUSD_M1_2013.zip
# 0 523320 51987406
# DAT_ASCII_SPXUSD_M1_2014.zip
# 938 524094 52510726
# DAT_ASCII_SPXUSD_M1_2015.zip
# 6052 524099 53034820
# DAT_ASCII_SPXUSD_M1_2016.zip
# 10924 521218 53558919
# DAT_ASCII_SPXUSD_M1_2017.zip
# 5 519779 54080137
# DAT_ASCII_SPXUSD_M1_2018.zip
# 16176 524144 54599916
# DAT_ASCII_SPXUSD_M1_2019.zip
# 10731 524054 55124060
# DAT_ASCII_SPXUSD_M1_2020.zip
# 90821 525494 55648114
# DAT_ASCII_UDXUSD_M1_2010.zip
# 696 67499 56173608
# DAT_ASCII_UDXUSD_M1_2011.zip
# 45118 521166 56241107
# DAT_ASCII_UDXUSD_M1_2012.zip
# 11592 523379 56762273
# DAT_ASCII_UDXUSD_M1_2013.zip
# 2172 523320 57285652
# DAT_ASCII_UDXUSD_M1_2014.zip
# 13548 524093 57808972
# DAT_ASCII_UDXUSD_M1_2015.zip
# 62382 524099 58333065
# DAT_ASCII_UDXUSD_M1_2016.zip
# 64553 524189 58857164
# DAT_ASCII_UDXUSD_M1_2017.zip
# 4407 519779 59381353
# DAT_ASCII_UDXUSD_M1_2018.zip
# 128507 524129 59901132
# DAT_ASCII_UDXUSD_M1_2019.zip
# 11826 523919 60425261
# DAT_ASCII_UDXUSD_M1_2020.zip
# 66539 525418 60949180
# DAT_ASCII_USDCAD_M1_2000.zip
# 0 76633 61474598
# DAT_ASCII_USDCAD_M1_2001.zip
# 0 523277 61551231
# DAT_ASCII_USDCAD_M1_2002.zip
# 0 523412 62074508
# DAT_ASCII_USDCAD_M1_2003.zip
# 432 523916 62597920
# DAT_ASCII_USDCAD_M1_2004.zip
# 7682 525449 63121836
# DAT_ASCII_USDCAD_M1_2005.zip
# 0 519310 63647285
# DAT_ASCII_USDCAD_M1_2006.zip
# 0 519691 64166595
# DAT_ASCII_USDCAD_M1_2007.zip
# 1 523977 64686286
# DAT_ASCII_USDCAD_M1_2008.zip
# 35 525419 65210263
# DAT_ASCII_USDCAD_M1_2009.zip
# 2192 524040 65735682
# DAT_ASCII_USDCAD_M1_2010.zip
# 5107 521158 66259722
# DAT_ASCII_USDCAD_M1_2011.zip
# 13869 521279 66780880
# DAT_ASCII_USDCAD_M1_2012.zip
# 92190 525059 67302159
# DAT_ASCII_USDCAD_M1_2013.zip
# 31825 524099 67827218
# DAT_ASCII_USDCAD_M1_2014.zip
# 41494 524159 68351317
# DAT_ASCII_USDCAD_M1_2015.zip
# 132914 524398 68875476
# DAT_ASCII_USDCAD_M1_2016.zip
# 182037 521278 69399874
# DAT_ASCII_USDCAD_M1_2017.zip
# 114499 520739 69921152
# DAT_ASCII_USDCAD_M1_2018.zip
# 107290 524159 70441891
# DAT_ASCII_USDCAD_M1_2019.zip
# 305772 524153 70966050
# DAT_ASCII_USDCAD_M1_2020.zip
# 240363 525599 71490203
# DAT_ASCII_USDCHF_M1_2000.zip
# 0 306365 72015802
# DAT_ASCII_USDCHF_M1_2001.zip
# 188 523273 72322167
# DAT_ASCII_USDCHF_M1_2002.zip
# 179 523414 72845440
# DAT_ASCII_USDCHF_M1_2003.zip
# 22694 523918 73368854
# DAT_ASCII_USDCHF_M1_2004.zip
# 14314 525447 73892772
# DAT_ASCII_USDCHF_M1_2005.zip
# 152 519311 74418219
# DAT_ASCII_USDCHF_M1_2006.zip
# 71 519687 74937530
# DAT_ASCII_USDCHF_M1_2007.zip
# 185 523978 75457217
# DAT_ASCII_USDCHF_M1_2008.zip
# 12760 525411 75981195
# DAT_ASCII_USDCHF_M1_2009.zip
# 20955 524038 76506606
# DAT_ASCII_USDCHF_M1_2010.zip
# 12717 521158 77030644
# DAT_ASCII_USDCHF_M1_2011.zip
# 15149 521279 77551802
# DAT_ASCII_USDCHF_M1_2012.zip
# 185940 525059 78073081
# DAT_ASCII_USDCHF_M1_2013.zip
# 157936 524099 78598140
# DAT_ASCII_USDCHF_M1_2014.zip
# 114645 524159 79122239
# DAT_ASCII_USDCHF_M1_2015.zip
# 152950 524398 79646398
# DAT_ASCII_USDCHF_M1_2016.zip
# 179394 521279 80170796
# DAT_ASCII_USDCHF_M1_2017.zip
# 152905 520739 80692075
# DAT_ASCII_USDCHF_M1_2018.zip
# 152155 524159 81212814
# DAT_ASCII_USDCHF_M1_2019.zip
# 173940 524155 81736973
# DAT_ASCII_USDCHF_M1_2020.zip
# 153517 525595 82261128
# DAT_ASCII_USDCZK_M1_2010.zip
# 9382 67560 82786723
# DAT_ASCII_USDCZK_M1_2011.zip
# 88958 521269 82854283
# DAT_ASCII_USDCZK_M1_2012.zip
# 69699 525050 83375552
# DAT_ASCII_USDCZK_M1_2013.zip
# 44345 524100 83900602
# DAT_ASCII_USDCZK_M1_2014.zip
# 15779 524158 84424702
# DAT_ASCII_USDCZK_M1_2015.zip
# 64759 524401 84948860
# DAT_ASCII_USDCZK_M1_2016.zip
# 110985 521278 85473261
# DAT_ASCII_USDCZK_M1_2017.zip
# 120532 520738 85994539
# DAT_ASCII_USDCZK_M1_2018.zip
# 132168 524157 86515277
# DAT_ASCII_USDCZK_M1_2019.zip
# 88959 524153 87039434
# DAT_ASCII_USDCZK_M1_2020.zip
# 102863 525593 87563587
# DAT_ASCII_USDDKK_M1_2008.zip
# 30647 175619 88089180
# DAT_ASCII_USDDKK_M1_2009.zip
# 64003 524040 88264799
# DAT_ASCII_USDDKK_M1_2010.zip
# 58910 521157 88788839
# DAT_ASCII_USDDKK_M1_2011.zip
# 149555 521278 89309996
# DAT_ASCII_USDDKK_M1_2012.zip
# 228021 525054 89831274
# DAT_ASCII_USDDKK_M1_2013.zip
# 211839 524100 90356328
# DAT_ASCII_USDDKK_M1_2014.zip
# 165402 524159 90880428
# DAT_ASCII_USDDKK_M1_2015.zip
# 207113 524399 91404587
# DAT_ASCII_USDDKK_M1_2016.zip
# 201409 521278 91928986
# DAT_ASCII_USDDKK_M1_2017.zip
# 174637 520738 92450264
# DAT_ASCII_USDDKK_M1_2018.zip
# 168017 524157 92971002
# DAT_ASCII_USDDKK_M1_2019.zip
# 240143 524153 93495159
# DAT_ASCII_USDDKK_M1_2020.zip
# 227442 525592 94019312
# DAT_ASCII_USDHKD_M1_2008.zip
# 0 175612 94544904
# DAT_ASCII_USDHKD_M1_2009.zip
# 0 523987 94720516
# DAT_ASCII_USDHKD_M1_2010.zip
# 0 521148 95244503
# DAT_ASCII_USDHKD_M1_2011.zip
# 0 521252 95765651
# DAT_ASCII_USDHKD_M1_2012.zip
# 0 525046 96286903
# DAT_ASCII_USDHKD_M1_2013.zip
# 0 524097 96811949
# DAT_ASCII_USDHKD_M1_2014.zip
# 0 524157 97336046
# DAT_ASCII_USDHKD_M1_2015.zip
# 0 524156 97860203
# DAT_ASCII_USDHKD_M1_2016.zip
# 0 521267 98384359
# DAT_ASCII_USDHKD_M1_2017.zip
# 0 520733 98905626
# DAT_ASCII_USDHKD_M1_2018.zip
# 0 524142 99426359
# DAT_ASCII_USDHKD_M1_2019.zip
# 546 524104 99950501
# DAT_ASCII_USDHKD_M1_2020.zip
# 280 525592 100474605
# DAT_ASCII_USDHUF_M1_2010.zip
# 9108 67554 101000197
# DAT_ASCII_USDHUF_M1_2011.zip
# 52377 521277 101067751
# DAT_ASCII_USDHUF_M1_2012.zip
# 80359 525057 101589028
# DAT_ASCII_USDHUF_M1_2013.zip
# 48499 524099 102114085
# DAT_ASCII_USDHUF_M1_2014.zip
# 21747 524158 102638184
# DAT_ASCII_USDHUF_M1_2015.zip
# 79177 524158 103162342
# DAT_ASCII_USDHUF_M1_2016.zip
# 87810 521278 103686500
# DAT_ASCII_USDHUF_M1_2017.zip
# 97010 520735 104207778
# DAT_ASCII_USDHUF_M1_2018.zip
# 106653 524095 104728513
# DAT_ASCII_USDHUF_M1_2019.zip
# 84916 524036 105252608
# DAT_ASCII_USDHUF_M1_2020.zip
# 105929 525475 105776644
# DAT_ASCII_USDJPY_M1_2000.zip
# 0 306330 106302119
# DAT_ASCII_USDJPY_M1_2001.zip
# 0 523278 106608449
# DAT_ASCII_USDJPY_M1_2002.zip
# 0 523414 107131727
# DAT_ASCII_USDJPY_M1_2003.zip
# 46748 523921 107655141
# DAT_ASCII_USDJPY_M1_2004.zip
# 9871 525450 108179062
# DAT_ASCII_USDJPY_M1_2005.zip
# 157 519310 108704512
# DAT_ASCII_USDJPY_M1_2006.zip
# 0 519690 109223822
# DAT_ASCII_USDJPY_M1_2007.zip
# 2156 523978 109743512
# DAT_ASCII_USDJPY_M1_2008.zip
# 20332 525419 110267490
# DAT_ASCII_USDJPY_M1_2009.zip
# 1244 524041 110792909
# DAT_ASCII_USDJPY_M1_2010.zip
# 2026 521158 111316950
# DAT_ASCII_USDJPY_M1_2011.zip
# 293 521279 111838108
# DAT_ASCII_USDJPY_M1_2012.zip
# 39512 525059 112359387
# DAT_ASCII_USDJPY_M1_2013.zip
# 175584 524100 112884446
# DAT_ASCII_USDJPY_M1_2014.zip
# 110788 524160 113408546
# DAT_ASCII_USDJPY_M1_2015.zip
# 234514 524397 113932706
# DAT_ASCII_USDJPY_M1_2016.zip
# 242307 521278 114457103
# DAT_ASCII_USDJPY_M1_2017.zip
# 226607 520739 114978381
# DAT_ASCII_USDJPY_M1_2018.zip
# 196303 524159 115499120
# DAT_ASCII_USDJPY_M1_2019.zip
# 223127 524159 116023279
# DAT_ASCII_USDJPY_M1_2020.zip
# 193601 525599 116547438
# DAT_ASCII_USDMXN_M1_2010.zip
# 170 67555 117073037
# DAT_ASCII_USDMXN_M1_2011.zip
# 8328 521258 117140592
# DAT_ASCII_USDMXN_M1_2012.zip
# 33188 525043 117661850
# DAT_ASCII_USDMXN_M1_2013.zip
# 18057 524100 118186893
# DAT_ASCII_USDMXN_M1_2014.zip
# 24246 524153 118710993
# DAT_ASCII_USDMXN_M1_2015.zip
# 24958 524073 119235146
# DAT_ASCII_USDMXN_M1_2016.zip
# 90669 521218 119759219
# DAT_ASCII_USDMXN_M1_2017.zip
# 51819 520699 120280437
# DAT_ASCII_USDMXN_M1_2018.zip
# 63894 524151 120801136
# DAT_ASCII_USDMXN_M1_2019.zip
# 138580 524153 121325287
# DAT_ASCII_USDMXN_M1_2020.zip
# 189863 525581 121849440
# DAT_ASCII_USDNOK_M1_2008.zip
# 12507 175619 122375021
# DAT_ASCII_USDNOK_M1_2009.zip
# 71237 524015 122550640
# DAT_ASCII_USDNOK_M1_2010.zip
# 73732 521156 123074655
# DAT_ASCII_USDNOK_M1_2011.zip
# 136913 521278 123595811
# DAT_ASCII_USDNOK_M1_2012.zip
# 204865 525057 124117089
# DAT_ASCII_USDNOK_M1_2013.zip
# 149625 524099 124642146
# DAT_ASCII_USDNOK_M1_2014.zip
# 111657 524107 125166245
# DAT_ASCII_USDNOK_M1_2015.zip
# 176482 524399 125690352
# DAT_ASCII_USDNOK_M1_2016.zip
# 157266 521278 126214751
# DAT_ASCII_USDNOK_M1_2017.zip
# 170127 520738 126736029
# DAT_ASCII_USDNOK_M1_2018.zip
# 173092 524156 127256767
# DAT_ASCII_USDNOK_M1_2019.zip
# 198663 524153 127780923
# DAT_ASCII_USDNOK_M1_2020.zip
# 200014 525594 128305076
# DAT_ASCII_USDPLN_M1_2010.zip
# 6800 67554 128830670
# DAT_ASCII_USDPLN_M1_2011.zip
# 89195 521208 128898224
# DAT_ASCII_USDPLN_M1_2012.zip
# 91780 525058 129419432
# DAT_ASCII_USDPLN_M1_2013.zip
# 58984 524100 129944490
# DAT_ASCII_USDPLN_M1_2014.zip
# 29586 524155 130468590
# DAT_ASCII_USDPLN_M1_2015.zip
# 74248 524401 130992745
# DAT_ASCII_USDPLN_M1_2016.zip
# 106859 521240 131517146
# DAT_ASCII_USDPLN_M1_2017.zip
# 90493 520738 132038386
# DAT_ASCII_USDPLN_M1_2018.zip
# 128208 524157 132559124
# DAT_ASCII_USDPLN_M1_2019.zip
# 200503 524159 133083281
# DAT_ASCII_USDPLN_M1_2020.zip
# 179826 525599 133607440
# DAT_ASCII_USDSEK_M1_2008.zip
# 13973 175619 134133039
# DAT_ASCII_USDSEK_M1_2009.zip
# 69103 524029 134308658
# DAT_ASCII_USDSEK_M1_2010.zip
# 71146 521157 134832687
# DAT_ASCII_USDSEK_M1_2011.zip
# 136443 521273 135353844
# DAT_ASCII_USDSEK_M1_2012.zip
# 205554 525056 135875117
# DAT_ASCII_USDSEK_M1_2013.zip
# 173348 524100 136400173
# DAT_ASCII_USDSEK_M1_2014.zip
# 159948 524157 136924273
# DAT_ASCII_USDSEK_M1_2015.zip
# 238563 524399 137448430
# DAT_ASCII_USDSEK_M1_2016.zip
# 236871 521276 137972829
# DAT_ASCII_USDSEK_M1_2017.zip
# 219724 520734 138494105
# DAT_ASCII_USDSEK_M1_2018.zip
# 196038 524156 139014839
# DAT_ASCII_USDSEK_M1_2019.zip
# 159764 524153 139538995
# DAT_ASCII_USDSEK_M1_2020.zip
# 200902 525593 140063148
# DAT_ASCII_USDSGD_M1_2008.zip
# 0 175593 140588741
# DAT_ASCII_USDSGD_M1_2009.zip
# 0 524038 140764334
# DAT_ASCII_USDSGD_M1_2010.zip
# 0 521151 141288372
# DAT_ASCII_USDSGD_M1_2011.zip
# 0 521264 141809523
# DAT_ASCII_USDSGD_M1_2012.zip
# 7067 525045 142330787
# DAT_ASCII_USDSGD_M1_2013.zip
# 0 524098 142855832
# DAT_ASCII_USDSGD_M1_2014.zip
# 1812 524156 143379930
# DAT_ASCII_USDSGD_M1_2015.zip
# 35791 524394 143904086
# DAT_ASCII_USDSGD_M1_2016.zip
# 93116 521278 144428480
# DAT_ASCII_USDSGD_M1_2017.zip
# 11715 520738 144949758
# DAT_ASCII_USDSGD_M1_2018.zip
# 29385 524157 145470496
# DAT_ASCII_USDSGD_M1_2019.zip
# 187748 524153 145994653
# DAT_ASCII_USDSGD_M1_2020.zip
# 106193 525599 146518806
# DAT_ASCII_USDTRY_M1_2010.zip
# 0 67554 147044405
# DAT_ASCII_USDTRY_M1_2011.zip
# 429 521080 147111959
# DAT_ASCII_USDTRY_M1_2012.zip
# 14452 525057 147633039
# DAT_ASCII_USDTRY_M1_2013.zip
# 7366 524090 148158096
# DAT_ASCII_USDTRY_M1_2014.zip
# 18836 524158 148682186
# DAT_ASCII_USDTRY_M1_2015.zip
# 30374 524160 149206344
# DAT_ASCII_USDTRY_M1_2016.zip
# 34318 521272 149730504
# DAT_ASCII_USDTRY_M1_2017.zip
# 20895 520737 150251776
# DAT_ASCII_USDTRY_M1_2018.zip
# 32445 524123 150772513
# DAT_ASCII_USDTRY_M1_2019.zip
# 184817 524156 151296636
# DAT_ASCII_USDTRY_M1_2020.zip
# 77550 525499 151820792
# DAT_ASCII_USDZAR_M1_2010.zip
# 264 67529 152346291
# DAT_ASCII_USDZAR_M1_2011.zip
# 1680 521017 152413820
# DAT_ASCII_USDZAR_M1_2012.zip
# 12816 525030 152934837
# DAT_ASCII_USDZAR_M1_2013.zip
# 5452 524097 153459867
# DAT_ASCII_USDZAR_M1_2014.zip
# 7349 524151 153983964
# DAT_ASCII_USDZAR_M1_2015.zip
# 25681 524159 154508115
# DAT_ASCII_USDZAR_M1_2016.zip
# 23634 521278 155032274
# DAT_ASCII_USDZAR_M1_2017.zip
# 8246 520738 155553552
# DAT_ASCII_USDZAR_M1_2018.zip
# 7234 524155 156074290
# DAT_ASCII_USDZAR_M1_2019.zip
# 127179 524091 156598445
# DAT_ASCII_USDZAR_M1_2020.zip
# 145971 525564 157122536
# DAT_ASCII_WTIUSD_M1_2010.zip
# 4358 67365 157648100
# DAT_ASCII_WTIUSD_M1_2011.zip
# 57664 521084 157715465
# DAT_ASCII_WTIUSD_M1_2012.zip
# 39876 523979 158236549
# DAT_ASCII_WTIUSD_M1_2013.zip
# 16428 524039 158760528
# DAT_ASCII_WTIUSD_M1_2014.zip
# 9349 524099 159284567
# DAT_ASCII_WTIUSD_M1_2015.zip
# 34702 524100 159808666
# DAT_ASCII_WTIUSD_M1_2016.zip
# 20155 521219 160332766
# DAT_ASCII_WTIUSD_M1_2017.zip
# 2353 519779 160853985
# DAT_ASCII_WTIUSD_M1_2018.zip
# 24682 524057 161373764
# DAT_ASCII_WTIUSD_M1_2019.zip
# 43267 524094 161897821
# DAT_ASCII_WTIUSD_M1_2020.zip
# 81138 525539 162421915
# DAT_ASCII_XAGUSD_M1_2009.zip
# 2529 348473 162947454
# DAT_ASCII_XAGUSD_M1_2010.zip
# 1437 521097 163295927
# DAT_ASCII_XAGUSD_M1_2011.zip
# 27926 521219 163817024
# DAT_ASCII_XAGUSD_M1_2012.zip
# 64722 524095 164338243
# DAT_ASCII_XAGUSD_M1_2013.zip
# 24061 524100 164862338
# DAT_ASCII_XAGUSD_M1_2014.zip
# 10090 524094 165386438
# DAT_ASCII_XAGUSD_M1_2015.zip
# 8678 524084 165910532
# DAT_ASCII_XAGUSD_M1_2016.zip
# 15744 521210 166434616
# DAT_ASCII_XAGUSD_M1_2017.zip
# 2462 519778 166955826
# DAT_ASCII_XAGUSD_M1_2018.zip
# 104477 524098 167475604
# DAT_ASCII_XAGUSD_M1_2019.zip
# 17984 524099 167999702
# DAT_ASCII_XAGUSD_M1_2020.zip
# 124883 525539 168523801
# DAT_ASCII_XAUUSD_M1_2009.zip
# 18548 419039 169049340
# DAT_ASCII_XAUUSD_M1_2010.zip
# 29535 521099 169468379
# DAT_ASCII_XAUUSD_M1_2011.zip
# 78796 521219 169989478
# DAT_ASCII_XAUUSD_M1_2012.zip
# 179373 524096 170510697
# DAT_ASCII_XAUUSD_M1_2013.zip
# 163379 524100 171034793
# DAT_ASCII_XAUUSD_M1_2014.zip
# 119931 524095 171558893
# DAT_ASCII_XAUUSD_M1_2015.zip
# 143170 524098 172082988
# DAT_ASCII_XAUUSD_M1_2016.zip
# 208326 521208 172607086
# DAT_ASCII_XAUUSD_M1_2017.zip
# 213619 519778 173128294
# DAT_ASCII_XAUUSD_M1_2018.zip
# 208824 524098 173648072
# DAT_ASCII_XAUUSD_M1_2019.zip
# 176104 524099 174172170
# DAT_ASCII_XAUUSD_M1_2020.zip
# 213332 525539 174696269

# %%
directory = '../FX-1-Minute-Data/output'
folders = [x[0].split('\\')[-1] for x in os.walk(directory)][1:]
data = []
for folder in folders:
    zip_files = [f for f in listdir(f'{directory}/{folder}') if f.endswith('.zip') and '2021' not in f]

    for file in zip_files:
        print(file)
        zip_file = ZipFile(f'{directory}/{folder}/{file}')
        df = pd.read_csv(zip_file.open(file[:-4]+'.csv'), names=['datetime', 'open', 'high', 'low', 'close', 'volume'], sep=';')
        df = df[['datetime', 'close']]
        df['datetime'] = df['datetime'].apply(lambda x: datetime.datetime.strptime(x, '%Y%m%d %H%M%S'))
        df = df.set_index('datetime')
        df = df[~df.index.duplicated()]
        df = df.resample('1T').fillna(None)
        
        temp = (~df.isna()).cumsum()
        seq_len = 301
        df['index'] = np.concatenate((((temp[seq_len:].values - temp[:-seq_len].values) == [seq_len])[:,0], [False]*seq_len))
        
        close_log = 100*50*(df.iloc[1:]['close'].values - df.iloc[:-1]['close'].values)/df.iloc[:-1]['close'].values
        close_log = np.concatenate(([None], np.sign(close_log)*np.log(abs(close_log)+1)))
        df['close_log'] = close_log
        df = df.iloc[1:]
        
        df = df.reset_index()
        idxs = df[df['index']].index
        prev_idxs = []
        count = 0
        for i in idxs:
            if i in prev_idxs:
                continue
#             if df.loc[i+2:i+513, 'close_log'].isna().sum() > 0:
#                 svdd
            data.append(df.loc[i+2:i+513, 'close_log'].values)
            prev_idxs = list(range(i+1, i+512))
            count += 1
        print(count, df['index'].sum(), len(df), len(data))
# Out:
# DAT_ASCII_AUDCAD_M1_2007.zip
# 24 3323 132468 24
# DAT_ASCII_AUDCAD_M1_2008.zip
# 208 45875 525418 232
# DAT_ASCII_AUDCAD_M1_2009.zip
# 401 114172 524040 633
# DAT_ASCII_AUDCAD_M1_2010.zip
# 409 118856 521155 1042
# DAT_ASCII_AUDCAD_M1_2011.zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2866f86c7785> in <module>
#      10         df = pd.read_csv(zip_file.open(file[:-4]+'.csv'), names=['datetime', 'open', 'high', 'low', 'close', 'volume'], sep=';')
#      11         df = df[['datetime', 'close']]
# ---> 12         df['datetime'] = df['datetime'].apply(lambda x: datetime.datetime.strptime(x, '%Y%m%d %H%M%S'))
#      13         df = df.set_index('datetime')
#      14         df = df[~df.index.duplicated()]
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-3-2866f86c7785> in <lambda>(x)
#      10         df = pd.read_csv(zip_file.open(file[:-4]+'.csv'), names=['datetime', 'open', 'high', 'low', 'close', 'volume'], sep=';')
#      11         df = df[['datetime', 'close']]
# ---> 12         df['datetime'] = df['datetime'].apply(lambda x: datetime.datetime.strptime(x, '%Y%m%d %H%M%S'))
#      13         df = df.set_index('datetime')
#      14         df = df[~df.index.duplicated()]
#
# c:\program files\python36\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# c:\program files\python36\lib\_strptime.py in _strptime(data_string, format)
#     332     with _cache_lock:
#     333         locale_time = _TimeRE_cache.locale_time
# --> 334         if (_getlang() != locale_time.lang or
#     335             time.tzname != locale_time.tzname or
#     336             time.daylight != locale_time.daylight):
#
# c:\program files\python36\lib\_strptime.py in _getlang()
#      29 def _getlang():
#      30     # Figure out what the current language is set to.
# ---> 31     return locale.getlocale(locale.LC_TIME)
#      32
#      33 class LocaleTime(object):
#
# c:\program files\python36\lib\locale.py in getlocale(category)
#     577     """
#     578     localename = _setlocale(category)
# --> 579     if category == LC_ALL and ';' in localename:
#     580         raise TypeError('category LC_ALL is not supported')
#     581     return _parse_localename(localename)
#
# KeyboardInterrupt:

# %%
directory = '../FX-1-Minute-Data/output'
folders = [x[0].split('\\')[-1] for x in os.walk(directory)][1:]
data = []
for folder in folders:
    zip_files = [f for f in listdir(f'{directory}/{folder}') if f.endswith('.zip') and '2021' not in f]

    for file in zip_files:
        print(file)
        zip_file = ZipFile(f'{directory}/{folder}/{file}')
        df = pd.read_csv(zip_file.open(file[:-4]+'.csv'), names=['datetime', 'open', 'high', 'low', 'close', 'volume'], sep=';')
        df = df[['datetime', 'close']]
        df['datetime'] = df['datetime'].apply(lambda x: datetime.datetime.strptime(x, '%Y%m%d %H%M%S'))
        df = df.set_index('datetime')
        df = df[~df.index.duplicated()]
        df = df.resample('1T').fillna(None)
        
        temp = (~df.isna()).cumsum()
        seq_len = 513
        df['index'] = np.concatenate((((temp[seq_len:].values - temp[:-seq_len].values) >= [0.9*seq_len])[:,0], [False]*seq_len))
        
        df = df.fillna(method='ffill')
        close_log = 100*50*(df.iloc[1:]['close'].values - df.iloc[:-1]['close'].values)/df.iloc[:-1]['close'].values
        close_log = np.concatenate(([None], np.sign(close_log)*np.log(abs(close_log)+1)))
        df['close_log'] = close_log
        df = df.iloc[1:]
        
        df = df.reset_index()
        idxs = df[df['index']].index
        prev_idxs = []
        count = 0
        for i in idxs:
            if i+2 in prev_idxs:
                continue
            seq = df.loc[i+2:i+seq_len]
            data.append(seq['close_log'].values)
            prev_idxs = list(range(i+2, i+seq_len))
            count += 1
        print(count*seq_len, df['index'].sum(), len(df), len(data))
# Out:
# DAT_ASCII_AUDCAD_M1_2007.zip
# 60021 52131 132468 117
# DAT_ASCII_AUDCAD_M1_2008.zip
# 322677 276478 525418 746
# DAT_ASCII_AUDCAD_M1_2009.zip
# 361665 339125 524040 1451
# DAT_ASCII_AUDCAD_M1_2010.zip
# 364230 341274 521155 2161
# DAT_ASCII_AUDCAD_M1_2011.zip
# 366795 343525 521278 2876
# DAT_ASCII_AUDCAD_M1_2012.zip
# 371412 350061 525056 3600
# DAT_ASCII_AUDCAD_M1_2013.zip
# 369360 348344 524099 4320
# DAT_ASCII_AUDCAD_M1_2014.zip

# %%
np.save('data/forex/all_forex_data_ffill_test.csv', data)

# %%
np.save('data/forex/all_usd_data2.csv', data)

# %%
np.save('data/forex/all_usd_data2_test.csv', data)

# %%
len(data)/3096720*2
# Out:
# 0.14972551602986386
